# %% [markdown]
# # 경기 데이터 전처리

# %%
import pandas as pd
from datetime import date

# %%
useful_attributes=['gameid','league','year','split','playerid','side','position','player','team','champion','result','date']

# %%
data_list=[]

# %%
year=['15','16','17','18','19','20','21']
file_directory='./data_before/match/'

# %%
season_duration={
                '15Spring':[date(2015,1,7),date(2015,4,12)],
                '15Summer':[date(2015,5,20),date(2015,8,14)],
                '16Spring':[date(2016,1,13),date(2016,4,10)],
                '16Summer':[date(2016,5,25),date(2016,8,7)],
                '17Spring':[date(2017,1,17),date(2017,4,3)],
                '17Summer':[date(2017,5,30),date(2017,8,7)],
                '18Spring':[date(2018,1,17),date(2018,3,26)],
                '18Summer':[date(2018,6,12),date(2018,8,10)],
                '19Spring':[date(2019,1,16),date(2019,4,1)],
                '19Summer':[date(2019,6,5),date(2019,8,19)],
                '20Spring':[date(2020,2,5),date(2020,4,17)],
                '20Summer':[date(2020,6,17),date(2020,8,24)],
                '21Spring':[date(2021,1,13),date(2021,3,1)]
                }

# %%
data=pd.read_csv("./data_before/match/16.csv",usecols=['date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51432 entries, 0 to 51431
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    51432 non-null  object
# dtypes: object(1)
# memory usage: 401.9+ KB

# %%
def change_pos_name(x):
    if x=='top':
        return 'Top'
    elif x=='jng':
        return 'Jungle'
    elif x=='mid':
        return 'Middle'
    elif x=='bot':
        return 'ADC'
    else:
        return 'Support'

# %%
def change_side_to_int(x):
    if x=='Blue':
        return 1
    else:
        return 0

# %%
for elem in year:
    
    data=pd.read_csv("{0}{1}.csv".format(file_directory,elem),usecols=useful_attributes)
 
    if elem=='15':
        cond1=data['league']=='LTC'
        data=data[cond1]
        data['league']=data['league'].apply(lambda x:'LCK')
    else:
        cond1=data['league']=='LCK'
        data=data[cond1]
        
        
        
    data.dropna(axis=0,inplace=True)
    data['side']=data['side'].apply(change_side_to_int)
    data['position']=data['position'].apply(change_pos_name)
    data_list.append(data)
# Out:
# C:\Users\skql5\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
all_data=pd.concat(data_list,axis=0,ignore_index=True)

# %%
all_data.set_index(['gameid'],inplace=True)

# %%
index=set(all_data.index)

# %%
index
# Out:
# {'TRKR1/960053',
#  'TRKR1/1070499',
#  'ESPORTSTMNT06/721201',
#  'TRKR1/950480',
#  'ESPORTSTMNT06/830159',
#  'TRKR1/550272',
#  'ESPORTSTMNT06/20710',
#  'ESPORTSTMNT06/70730',
#  'ESPORTSTMNT03/1813217',
#  'ESPORTSTMNT03/2073841',
#  'TRKR1/600089',
#  'ESPORTSTMNT06/250623',
#  'TRKR1/1150674',
#  'ESPORTSTMNT03/1141615',
#  'ESPORTSTMNT01/1434821',
#  'ESPORTSTMNT02/1293762',
#  'TRKR1/910488',
#  'ESPORTSTMNT02/981910',
#  'ESPORTSTMNT06/720686',
#  'ESPORTSTMNT06/721603',
#  'ESPORTSTMNT06/551074',
#  'ESPORTSTMNT02/1084133',
#  'ESPORTSTMNT03/2007653',
#  'ESPORTSTMNT01/2139025',
#  'ESPORTSTMNT06/770540',
#  'TRKR1/730327',
#  'ESPORTSTMNT01/1060564',
#  'ESPORTSTMNT03/1415803',
#  'TRKR1/1170568',
#  'ESPORTSTMNT06/720136',
#  'TRKR1/720401',
#  'ESPORTSTMNT01/1325596',
#  'ESPORTSTMNT03/1752600',
#  'ESPORTSTMNT05/1830093',
#  'ESPORTSTMNT02/1770137',
#  'ESPORTSTMNT06/560235',
#  'ESPORTSTMNT06/610634',
#  'ESPORTSTMNT01/1131870',
#  'TRKR1/1090494',
#  'ESPORTSTMNT06/280143',
#  'ESPORTSTMNT06/320200',
#  'TRKR1/890064',
#  'TRKR1/1040879',
#  'ESPORTSTMNT03/1404085',
#  'TRKR1/1090471',
#  'TRKR1/490037',
#  'ESPORTSTMNT01/1415378',
#  'ESPORTSTMNT02/1936296',
#  'ESPORTSTMNT06/351146',
#  'ESPORTSTMNT06/550246',
#  'ESPORTSTMNT06/31272',
#  'ESPORTSTMNT01/1060524',
#  'ESPORTSTMNT03/1757884',
#  'ESPORTSTMNT06/170165',
#  'ESPORTSTMNT06/550950',
#  'ESPORTSTMNT06/590374',
#  'ESPORTSTMNT02/1012323',
#  'ESPORTSTMNT02/1414857',
#  'ESPORTSTMNT01/1426060',
#  'ESPORTSTMNT06/270733',
#  'ESPORTSTMNT03/1023628',
#  'TRKR1/610209',
#  'ESPORTSTMNT06/581069',
#  'TRKR1/970057',
#  'ESPORTSTMNT01/1071569',
#  'ESPORTSTMNT01/1693567',
#  'ESPORTSTMNT03/1125069',
#  'TRKR1/990034',
#  'ESPORTSTMNT06/81073',
#  'ESPORTSTMNT02/1324783',
#  'ESPORTSTMNT03/1141035',
#  'ESPORTSTMNT06/40515',
#  'ESPORTSTMNT02/1927485',
#  'ESPORTSTMNT01/1041495',
#  'ESPORTSTMNT06/20750',
#  'TRKR1/1040241',
#  'TRKR1/920035',
#  'ESPORTSTMNT02/1770153',
#  'ESPORTSTMNT06/610665',
#  'ESPORTSTMNT06/641651',
#  'ESPORTSTMNT06/601080',
#  'TRKR1/960370',
#  'ESPORTSTMNT02/1090924',
#  'ESPORTSTMNT06/721302',
#  'ESPORTSTMNT02/1091363',
#  'TRKR1/1020102',
#  'TRKR1/540037',
#  'ESPORTSTMNT06/550789',
#  'ESPORTSTMNT06/551140',
#  'TRKR1/1140786',
#  'ESPORTSTMNT03/1341601',
#  'ESPORTSTMNT03/1353412',
#  'ESPORTSTMNT03/2101680',
#  'ESPORTSTMNT06/270615',
#  'ESPORTSTMNT06/41034',
#  'ESPORTSTMNT03/1024117',
#  'ESPORTSTMNT01/1041911',
#  'ESPORTSTMNT02/1292653',
#  'ESPORTSTMNT02/982640',
#  'TRKR1/680114',
#  'ESPORTSTMNT06/771712',
#  'ESPORTSTMNT02/1002267',
#  'ESPORTSTMNT06/90308',
#  'ESPORTSTMNT06/280138',
#  'ESPORTSTMNT06/780398',
#  'ESPORTSTMNT03/1023353',
#  'ESPORTSTMNT02/1024543',
#  'TRKR1/1050059',
#  'ESPORTSTMNT02/1031753',
#  'ESPORTSTMNT03/1405661',
#  'ESPORTSTMNT06/250606',
#  'ESPORTSTMNT01/1151650',
#  'TRKR1/1150031',
#  'TRKR1/1040059',
#  'ESPORTSTMNT05/1200105',
#  'ESPORTSTMNT02/1333365',
#  'ESPORTSTMNT06/31275',
#  'ESPORTSTMNT02/1024532',
#  'ESPORTSTMNT03/1415806',
#  'ESPORTSTMNT06/610849',
#  'TRKR1/1110540',
#  'ESPORTSTMNT05/1820513',
#  'ESPORTSTMNT06/551204',
#  'TRKR1/1170566',
#  'TRKR1/600176',
#  'TRKR1/1020449',
#  'ESPORTSTMNT02/1286938',
#  'TRKR1/1130302',
#  'TRKR1/580020',
#  'TRKR1/640115',
#  'TRKR1/1090666',
#  'TRKR1/640028',
#  'ESPORTSTMNT02/1294719',
#  'TRKR1/1100139',
#  'ESPORTSTMNT06/140364',
#  'ESPORTSTMNT03/1033408',
#  'ESPORTSTMNT03/1332688',
#  'TRKR1/950641',
#  'ESPORTSTMNT02/1333734',
#  'ESPORTSTMNT06/750169',
#  'ESPORTSTMNT01/1436333',
#  'ESPORTSTMNT01/1041535',
#  'ESPORTSTMNT01/1414864',
#  'ESPORTSTMNT06/330942',
#  'ESPORTSTMNT01/1293312',
#  'ESPORTSTMNT06/650517',
#  'ESPORTSTMNT01/1134226',
#  'ESPORTSTMNT06/830167',
#  'TRKR1/600085',
#  'TRKR1/1120466',
#  'ESPORTSTMNT03/1352557',
#  'TRKR1/1070643',
#  'ESPORTSTMNT06/830129',
#  'ESPORTSTMNT01/1415487',
#  'ESPORTSTMNT03/1141004',
#  'TRKR1/580022',
#  'ESPORTSTMNT06/130257',
#  'ESPORTSTMNT03/1341572',
#  'ESPORTSTMNT03/2074792',
#  'ESPORTSTMNT01/1424337',
#  'TRKR1/1160290',
#  'ESPORTSTMNT06/761971',
#  'ESPORTSTMNT03/1031391',
#  'ESPORTSTMNT06/60899',
#  'ESPORTSTMNT06/550356',
#  'ESPORTSTMNT06/731255',
#  'ESPORTSTMNT02/1724893',
#  'ESPORTSTMNT03/2054312',
#  'TRKR1/1030618',
#  'ESPORTSTMNT04/1140532',
#  'TRKR1/660303',
#  'ESPORTSTMNT06/580848',
#  'ESPORTSTMNT01/1144770',
#  'TRKR1/590145',
#  'ESPORTSTMNT03/2091944',
#  'ESPORTSTMNT01/1325005',
#  'ESPORTSTMNT03/1403547',
#  'ESPORTSTMNT01/1325819',
#  'ESPORTSTMNT06/771337',
#  'ESPORTSTMNT02/1093310',
#  'TRKR1/1100389',
#  'TRKR1/450248',
#  'TRKR1/640122',
#  'ESPORTSTMNT06/651491',
#  'ESPORTSTMNT03/1123055',
#  'ESPORTSTMNT02/1323018',
#  'ESPORTSTMNT03/1341536',
#  'ESPORTSTMNT01/2139386',
#  'ESPORTSTMNT06/40397',
#  'TRKR1/470083',
#  'ESPORTSTMNT01/1031941',
#  'ESPORTSTMNT02/1032986',
#  'ESPORTSTMNT06/560345',
#  'ESPORTSTMNT06/41017',
#  'ESPORTSTMNT06/650769',
#  'ESPORTSTMNT01/1683151',
#  'TRKR1/1010399',
#  'TRKR1/450304',
#  'TRKR1/1080457',
#  'ESPORTSTMNT06/551862',
#  'ESPORTSTMNT02/1101574',
#  'ESPORTSTMNT03/1403610',
#  'ESPORTSTMNT03/1033738',
#  'TRKR1/760075',
#  'TRKR1/1090611',
#  'TRKR1/1080678',
#  'ESPORTSTMNT06/310560',
#  'ESPORTSTMNT06/740484',
#  'ESPORTSTMNT06/320047',
#  'ESPORTSTMNT01/1324954',
#  'ESPORTSTMNT06/771077',
#  'ESPORTSTMNT06/620615',
#  'ESPORTSTMNT01/1165430',
#  'TRKR1/600106',
#  'ESPORTSTMNT01/1415382',
#  'ESPORTSTMNT02/1287048',
#  'ESPORTSTMNT06/250218',
#  'TRKR1/680113',
#  'ESPORTSTMNT06/780647',
#  'ESPORTSTMNT06/250503',
#  'ESPORTSTMNT02/1332637',
#  'TRKR1/1020108',
#  'ESPORTSTMNT06/541425',
#  'ESPORTSTMNT01/1325077',
#  'TRKR1/500299',
#  'TRKR1/1010377',
#  'ESPORTSTMNT06/90741',
#  'ESPORTSTMNT06/320274',
#  'ESPORTSTMNT06/610809',
#  'ESPORTSTMNT06/60570',
#  'ESPORTSTMNT01/1294725',
#  'ESPORTSTMNT01/1130786',
#  'ESPORTSTMNT06/760796',
#  'ESPORTSTMNT06/50331',
#  'TRKR1/1070930',
#  'ESPORTSTMNT06/541307',
#  'ESPORTSTMNT02/1684302',
#  'ESPORTSTMNT03/1767577',
#  'ESPORTSTMNT06/90917',
#  'ESPORTSTMNT01/1415320',
#  'TRKR1/440073',
#  'ESPORTSTMNT06/240141',
#  'ESPORTSTMNT01/1134154',
#  'ESPORTSTMNT01/1081262',
#  'ESPORTSTMNT03/1823928',
#  'ESPORTSTMNT06/270684',
#  'TRKR1/760225',
#  'ESPORTSTMNT06/600353',
#  'ESPORTSTMNT02/1296215',
#  'TRKR1/440328',
#  'ESPORTSTMNT06/560111',
#  'ESPORTSTMNT01/2136300',
#  'TRKR1/610063',
#  'ESPORTSTMNT06/310782',
#  'ESPORTSTMNT02/1000799',
#  'ESPORTSTMNT06/772620',
#  'ESPORTSTMNT06/70373',
#  'TRKR1/960524',
#  'ESPORTSTMNT06/590392',
#  'TRKR1/1130353',
#  'ESPORTSTMNT02/1324690',
#  'TRKR1/950503',
#  'ESPORTSTMNT02/1021779',
#  'ESPORTSTMNT02/1324372',
#  'TRKR1/1140715',
#  'ESPORTSTMNT03/1128297',
#  'ESPORTSTMNT02/1295891',
#  'ESPORTSTMNT01/1690580',
#  'ESPORTSTMNT01/2139164',
#  'ESPORTSTMNT06/771285',
#  'ESPORTSTMNT03/1143971',
#  'TRKR1/630310',
#  'ESPORTSTMNT06/770800',
#  'ESPORTSTMNT06/300787',
#  'ESPORTSTMNT01/1887149',
#  'TRKR1/1090280',
#  'ESPORTSTMNT06/250438',
#  'TRKR1/480130',
#  'TRKR1/1020246',
#  'ESPORTSTMNT01/1415210',
#  'ESPORTSTMNT03/1351846',
#  'ESPORTSTMNT06/770753',
#  'ESPORTSTMNT06/240103',
#  'TRKR1/1140705',
#  'ESPORTSTMNT06/20985',
#  'ESPORTSTMNT06/40924',
#  'ESPORTSTMNT01/1434787',
#  'TRKR1/440185',
#  'ESPORTSTMNT06/270074',
#  'ESPORTSTMNT06/790603',
#  'ESPORTSTMNT06/830259',
#  'ESPORTSTMNT06/720662',
#  'ESPORTSTMNT01/1162877',
#  'TRKR1/450501',
#  'ESPORTSTMNT06/80891',
#  'TRKR1/1180453',
#  'ESPORTSTMNT01/1683165',
#  'ESPORTSTMNT06/140363',
#  'ESPORTSTMNT02/2067551',
#  'TRKR1/660061',
#  'ESPORTSTMNT06/610136',
#  'ESPORTSTMNT01/1425772',
#  'ESPORTSTMNT03/1442192',
#  'ESPORTSTMNT06/761475',
#  'TRKR1/450392',
#  'TRKR1/960071',
#  'ESPORTSTMNT02/1960496',
#  'TRKR1/1140814',
#  'TRKR1/700100',
#  'ESPORTSTMNT02/1386267',
#  'ESPORTSTMNT01/1730173',
#  'ESPORTSTMNT03/1023398',
#  'ESPORTSTMNT01/1720608',
#  'ESPORTSTMNT06/301031',
#  'ESPORTSTMNT02/1034224',
#  'ESPORTSTMNT02/1083593',
#  'ESPORTSTMNT01/2137369',
#  'ESPORTSTMNT06/50540',
#  'ESPORTSTMNT06/130528',
#  'TRKR1/610026',
#  'ESPORTSTMNT06/730459',
#  'ESPORTSTMNT02/1032255',
#  'ESPORTSTMNT01/1896801',
#  'ESPORTSTMNT01/1060904',
#  'ESPORTSTMNT02/2067168',
#  'ESPORTSTMNT06/791091',
#  'ESPORTSTMNT02/1324511',
#  'ESPORTSTMNT06/110044',
#  'ESPORTSTMNT03/1752678',
#  'ESPORTSTMNT06/790672',
#  'TRKR1/1030197',
#  'ESPORTSTMNT01/1883256',
#  'ESPORTSTMNT01/1415201',
#  'ESPORTSTMNT05/1831251',
#  'ESPORTSTMNT06/40580',
#  'ESPORTSTMNT06/720884',
#  'ESPORTSTMNT06/560533',
#  'ESPORTSTMNT06/70728',
#  'ESPORTSTMNT01/1140917',
#  'ESPORTSTMNT01/1061222',
#  'ESPORTSTMNT02/1294153',
#  'ESPORTSTMNT02/1734480',
#  'ESPORTSTMNT06/80219',
#  'TRKR1/720220',
#  'TRKR1/1080430',
#  'TRKR1/1120613',
#  'ESPORTSTMNT01/1293885',
#  'ESPORTSTMNT01/1415469',
#  'TRKR1/1180143',
#  'TRKR1/1040465',
#  'ESPORTSTMNT02/1004897',
#  'ESPORTSTMNT06/591312',
#  'ESPORTSTMNT06/772486',
#  'ESPORTSTMNT01/1885129',
#  'ESPORTSTMNT06/81186',
#  'ESPORTSTMNT06/340860',
#  'ESPORTSTMNT02/1287168',
#  'ESPORTSTMNT02/2065070',
#  'TRKR1/990104',
#  'ESPORTSTMNT06/650291',
#  'ESPORTSTMNT06/60780',
#  'ESPORTSTMNT06/300361',
#  'ESPORTSTMNT01/1306343',
#  'ESPORTSTMNT01/2136378',
#  'ESPORTSTMNT06/250224',
#  'ESPORTSTMNT06/260176',
#  'ESPORTSTMNT02/1032253',
#  'TRKR1/610155',
#  'ESPORTSTMNT01/1887197',
#  'ESPORTSTMNT03/1997562',
#  'ESPORTSTMNT06/720742',
#  'ESPORTSTMNT06/260143',
#  'ESPORTSTMNT02/1091192',
#  'ESPORTSTMNT02/1684151',
#  'ESPORTSTMNT03/1433021',
#  'TRKR1/1090324',
#  'TRKR1/640285',
#  'ESPORTSTMNT06/740777',
#  'ESPORTSTMNT01/1414831',
#  'ESPORTSTMNT02/1394295',
#  'TRKR1/640267',
#  'ESPORTSTMNT06/140673',
#  'ESPORTSTMNT06/50861',
#  'ESPORTSTMNT03/1995310',
#  'ESPORTSTMNT01/1060914',
#  'ESPORTSTMNT01/1415112',
#  'ESPORTSTMNT06/90303',
#  'ESPORTSTMNT06/170180',
#  'TRKR1/1010043',
#  'ESPORTSTMNT03/1343345',
#  'ESPORTSTMNT02/2075641',
#  'TRKR1/1180446',
#  'ESPORTSTMNT06/641858',
#  'ESPORTSTMNT06/550791',
#  'ESPORTSTMNT02/1034269',
#  'ESPORTSTMNT02/992747',
#  'TRKR1/1160150',
#  'TRKR1/540096',
#  'TRKR1/1140817',
#  'ESPORTSTMNT06/310156',
#  'TRKR1/480129',
#  'ESPORTSTMNT02/1080561',
#  'ESPORTSTMNT02/1295808',
#  'ESPORTSTMNT01/1730332',
#  'TRKR1/440323',
#  'ESPORTSTMNT03/1332603',
#  'ESPORTSTMNT03/1767595',
#  'TRKR1/610025',
#  'TRKR1/700044',
#  'ESPORTSTMNT03/1813262',
#  'ESPORTSTMNT03/1021668',
#  'TRKR1/1040609',
#  'ESPORTSTMNT06/651267',
#  'TRKR1/1170499',
#  'ESPORTSTMNT06/300758',
#  'TRKR1/670040',
#  'ESPORTSTMNT02/1403265',
#  'TRKR1/1040553',
#  'ESPORTSTMNT06/771177',
#  'TRKR1/740277',
#  'TRKR1/960304',
#  'ESPORTSTMNT02/2067242',
#  'ESPORTSTMNT06/540842',
#  'ESPORTSTMNT03/2074922',
#  'ESPORTSTMNT01/1305624',
#  'ESPORTSTMNT06/740394',
#  'ESPORTSTMNT01/1043122',
#  'TRKR1/740268',
#  'ESPORTSTMNT06/721613',
#  'ESPORTSTMNT01/1051679',
#  'TRKR1/1110350',
#  'TRKR1/610203',
#  'TRKR1/1030631',
#  'ESPORTSTMNT05/1821628',
#  'ESPORTSTMNT01/1896808',
#  'ESPORTSTMNT06/30826',
#  'ESPORTSTMNT01/1043218',
#  'TRKR1/1100379',
#  'TRKR1/680075',
#  'ESPORTSTMNT06/90761',
#  'ESPORTSTMNT03/1752558',
#  'TRKR1/760076',
#  'TRKR1/600174',
#  'ESPORTSTMNT01/1084580',
#  'ESPORTSTMNT02/1024733',
#  'ESPORTSTMNT02/1013656',
#  'ESPORTSTMNT06/140928',
#  'TRKR1/960600',
#  'ESPORTSTMNT02/1295849',
#  'ESPORTSTMNT01/1305850',
#  'ESPORTSTMNT01/1084219',
#  'TRKR1/890125',
#  'TRKR1/1030901',
#  'TRKR1/950643',
#  'TRKR1/450443',
#  'ESPORTSTMNT01/1325025',
#  'ESPORTSTMNT03/1443415',
#  'TRKR1/1080369',
#  'ESPORTSTMNT06/260940',
#  'ESPORTSTMNT01/1436576',
#  'ESPORTSTMNT02/1014171',
#  'ESPORTSTMNT06/50204',
#  'TRKR1/960177',
#  'TRKR1/1070150',
#  'ESPORTSTMNT06/721794',
#  'ESPORTSTMNT06/761477',
#  'ESPORTSTMNT01/1414874',
#  'ESPORTSTMNT06/240148',
#  'ESPORTSTMNT01/1133666',
#  'ESPORTSTMNT06/340187',
#  'ESPORTSTMNT06/240086',
#  'ESPORTSTMNT06/550585',
#  'TRKR1/1070225',
#  'ESPORTSTMNT03/1031350',
#  'ESPORTSTMNT02/1030895',
#  'ESPORTSTMNT03/1765213',
#  'ESPORTSTMNT06/270975',
#  'TRKR1/1070279',
#  'TRKR1/910209',
#  'ESPORTSTMNT06/731750',
#  'TRKR1/1130310',
#  'ESPORTSTMNT06/641682',
#  'ESPORTSTMNT06/550247',
#  'ESPORTSTMNT06/620167',
#  'TRKR1/990398',
#  'ESPORTSTMNT03/1404095',
#  'ESPORTSTMNT03/1441817',
#  'TRKR1/600086',
#  'ESPORTSTMNT05/1820504',
#  'ESPORTSTMNT06/800691',
#  'ESPORTSTMNT02/1324382',
#  'ESPORTSTMNT06/50207',
#  'ESPORTSTMNT03/1814382',
#  'TRKR1/570016',
#  'ESPORTSTMNT06/731666',
#  'ESPORTSTMNT03/1341565',
#  'TRKR1/680063',
#  'ESPORTSTMNT02/1735199',
#  'TRKR1/440131',
#  'ESPORTSTMNT06/270696',
#  'ESPORTSTMNT03/2091920',
#  'ESPORTSTMNT02/1324352',
#  'ESPORTSTMNT06/140120',
#  'TRKR1/1160277',
#  'ESPORTSTMNT01/1690828',
#  'ESPORTSTMNT06/81179',
#  'ESPORTSTMNT05/1831273',
#  'ESPORTSTMNT03/2007552',
#  'ESPORTSTMNT06/810035',
#  'ESPORTSTMNT06/830053',
#  'ESPORTSTMNT06/360271',
#  'TRKR1/1170118',
#  'ESPORTSTMNT01/1162529',
#  'ESPORTSTMNT01/1294738',
#  'TRKR1/610197',
#  'ESPORTSTMNT06/320036',
#  'ESPORTSTMNT06/730255',
#  'TRKR1/700402',
#  'ESPORTSTMNT02/1011955',
#  'ESPORTSTMNT03/1997175',
#  'ESPORTSTMNT02/1770266',
#  'ESPORTSTMNT02/1014180',
#  'ESPORTSTMNT02/1960124',
#  'ESPORTSTMNT06/140696',
#  'ESPORTSTMNT02/1396149',
#  'ESPORTSTMNT02/1021616',
#  'ESPORTSTMNT02/1010799',
#  'ESPORTSTMNT06/610102',
#  'ESPORTSTMNT02/1384018',
#  'ESPORTSTMNT02/1384813',
#  'ESPORTSTMNT06/330987',
#  'ESPORTSTMNT06/70781',
#  'ESPORTSTMNT06/140826',
#  'TRKR1/650050',
#  'TRKR1/760219',
#  'ESPORTSTMNT06/40607',
#  'ESPORTSTMNT01/1051434',
#  'ESPORTSTMNT01/1152631',
#  'ESPORTSTMNT02/1936280',
#  'TRKR1/1080428',
#  'ESPORTSTMNT06/772365',
#  'ESPORTSTMNT01/1043203',
#  'ESPORTSTMNT01/1405646',
#  'ESPORTSTMNT06/280255',
#  'ESPORTSTMNT03/1414435',
#  'ESPORTSTMNT03/1766665',
#  'ESPORTSTMNT01/1041724',
#  'TRKR1/1090612',
#  'ESPORTSTMNT02/1081687',
#  'TRKR1/1140666',
#  'ESPORTSTMNT03/1443471',
#  'ESPORTSTMNT02/1323134',
#  'ESPORTSTMNT06/170186',
#  'TRKR1/480093',
#  'ESPORTSTMNT03/1764690',
#  'TRKR1/720186',
#  'ESPORTSTMNT06/641669',
#  'TRKR1/1000462',
#  'ESPORTSTMNT06/280219',
#  'ESPORTSTMNT02/1415120',
#  'ESPORTSTMNT03/1022932',
#  'TRKR1/560093',
#  'ESPORTSTMNT06/720648',
#  'ESPORTSTMNT06/110036',
#  'ESPORTSTMNT03/1764730',
#  'ESPORTSTMNT03/1757878',
#  'ESPORTSTMNT03/1757821',
#  'TRKR1/1010153',
#  'ESPORTSTMNT06/90604',
#  'ESPORTSTMNT02/1080611',
#  'ESPORTSTMNT03/1441822',
#  'ESPORTSTMNT06/550432',
#  'ESPORTSTMNT02/2064994',
#  'ESPORTSTMNT06/641694',
#  'ESPORTSTMNT02/1403226',
#  'ESPORTSTMNT02/2076321',
#  'ESPORTSTMNT01/1081886',
#  'ESPORTSTMNT06/720143',
#  'ESPORTSTMNT02/1013702',
#  'ESPORTSTMNT02/1080533',
#  'ESPORTSTMNT06/170170',
#  'TRKR1/570086',
#  'TRKR1/670318',
#  'ESPORTSTMNT01/1041504',
#  'ESPORTSTMNT03/1144057',
#  'ESPORTSTMNT02/2067194',
#  'ESPORTSTMNT02/1960276',
#  'ESPORTSTMNT06/90577',
#  'TRKR1/1140526',
#  'ESPORTSTMNT06/790940',
#  'ESPORTSTMNT03/1415826',
#  'TRKR1/1150701',
#  'ESPORTSTMNT03/1404039',
#  'TRKR1/440055',
#  'ESPORTSTMNT03/1332659',
#  'ESPORTSTMNT01/2136415',
#  'ESPORTSTMNT02/1283186',
#  'TRKR1/1090325',
#  'ESPORTSTMNT06/30437',
#  'ESPORTSTMNT01/1426092',
#  'ESPORTSTMNT06/650508',
#  'ESPORTSTMNT06/150413',
#  'ESPORTSTMNT02/1102215',
#  'ESPORTSTMNT06/551568',
#  'ESPORTSTMNT01/1306112',
#  'ESPORTSTMNT02/1733852',
#  'ESPORTSTMNT02/1082052',
#  'ESPORTSTMNT06/90738',
#  'TRKR1/640227',
#  'TRKR1/1020465',
#  'ESPORTSTMNT06/590351',
#  'ESPORTSTMNT06/790612',
#  'ESPORTSTMNT01/1134136',
#  'TRKR1/610150',
#  'ESPORTSTMNT01/1302595',
#  'TRKR1/1160610',
#  'ESPORTSTMNT06/560547',
#  'ESPORTSTMNT06/772478',
#  'ESPORTSTMNT01/1296710',
#  'ESPORTSTMNT02/1102272',
#  'ESPORTSTMNT01/2139015',
#  'ESPORTSTMNT06/260104',
#  'ESPORTSTMNT06/771203',
#  'ESPORTSTMNT06/780129',
#  'ESPORTSTMNT02/1684227',
#  'ESPORTSTMNT03/1431664',
#  'ESPORTSTMNT06/762491',
#  'ESPORTSTMNT06/780266',
#  'ESPORTSTMNT01/1887206',
#  'ESPORTSTMNT01/1131058',
#  'TRKR1/510167',
#  'TRKR1/950350',
#  'ESPORTSTMNT03/1031118',
#  'ESPORTSTMNT06/731229',
#  'ESPORTSTMNT01/1031972',
#  'TRKR1/1150594',
#  'TRKR1/700398',
#  'TRKR1/990094',
#  'ESPORTSTMNT03/1752582',
#  'ESPORTSTMNT01/1690549',
#  'ESPORTSTMNT01/2136290',
#  'ESPORTSTMNT06/270019',
#  'TRKR1/1140767',
#  'ESPORTSTMNT02/1294235',
#  'ESPORTSTMNT06/40067',
#  'TRKR1/640090',
#  'ESPORTSTMNT06/550970',
#  'ESPORTSTMNT01/1161505',
#  'ESPORTSTMNT01/1883825',
#  'TRKR1/920449',
#  'ESPORTSTMNT06/610146',
#  'ESPORTSTMNT01/1436394',
#  'ESPORTSTMNT06/260109',
#  'ESPORTSTMNT02/1034081',
#  'ESPORTSTMNT02/1736533',
#  'TRKR1/720428',
#  'ESPORTSTMNT02/1094190',
#  'TRKR1/900155',
#  'TRKR1/500294',
#  'ESPORTSTMNT05/1820337',
#  'TRKR1/1170563',
#  'TRKR1/910486',
#  'ESPORTSTMNT02/1286670',
#  'TRKR1/610210',
#  'ESPORTSTMNT06/260140',
#  'ESPORTSTMNT06/240162',
#  'ESPORTSTMNT01/1144778',
#  'ESPORTSTMNT01/1131604',
#  'ESPORTSTMNT06/250898',
#  'ESPORTSTMNT02/1296174',
#  'TRKR1/1170484',
#  'ESPORTSTMNT02/1102211',
#  'ESPORTSTMNT06/551605',
#  'ESPORTSTMNT02/1384046',
#  'ESPORTSTMNT03/1413045',
#  'TRKR1/1160199',
#  'ESPORTSTMNT03/1032916',
#  'ESPORTSTMNT03/1997159',
#  'TRKR1/1090069',
#  'ESPORTSTMNT02/1404245',
#  'TRKR1/700097',
#  'ESPORTSTMNT06/770432',
#  'ESPORTSTMNT02/1083574',
#  'TRKR1/1150679',
#  'ESPORTSTMNT02/1093323',
#  'ESPORTSTMNT06/580830',
#  'ESPORTSTMNT03/1140467',
#  'TRKR1/650140',
#  'ESPORTSTMNT06/270558',
#  'ESPORTSTMNT02/1324713',
#  'TRKR1/1040887',
#  'TRKR1/640098',
#  'ESPORTSTMNT02/2076330',
#  'ESPORTSTMNT01/1143542',
#  'ESPORTSTMNT01/1415198',
#  'ESPORTSTMNT06/90937',
#  'TRKR1/1080861',
#  'ESPORTSTMNT03/1141045',
#  'TRKR1/730065',
#  'TRKR1/910222',
#  'TRKR1/660063',
#  'ESPORTSTMNT06/601045',
#  'TRKR1/730313',
#  'ESPORTSTMNT05/1830074',
#  'ESPORTSTMNT01/1887363',
#  'TRKR1/950043',
#  'ESPORTSTMNT03/1143990',
#  'TRKR1/710456',
#  'ESPORTSTMNT06/310088',
#  'ESPORTSTMNT06/610265',
#  'TRKR1/700115',
#  'ESPORTSTMNT02/1293792',
#  'ESPORTSTMNT02/1023979',
#  'TRKR1/690322',
#  'ESPORTSTMNT03/1994703',
#  'ESPORTSTMNT01/1083645',
#  'ESPORTSTMNT01/1315397',
#  'ESPORTSTMNT02/1112427',
#  'ESPORTSTMNT02/1323090',
#  'TRKR1/450078',
#  'ESPORTSTMNT06/130549',
#  'ESPORTSTMNT06/250504',
#  'ESPORTSTMNT02/1322260',
#  'ESPORTSTMNT06/110062',
#  'ESPORTSTMNT06/140710',
#  'ESPORTSTMNT03/1352548',
#  'ESPORTSTMNT06/280155',
#  'ESPORTSTMNT01/1691701',
#  'ESPORTSTMNT03/1752579',
#  'ESPORTSTMNT02/1970528',
#  'ESPORTSTMNT06/610638',
#  'ESPORTSTMNT06/610658',
#  'ESPORTSTMNT02/1970431',
#  'ESPORTSTMNT06/140392',
#  'ESPORTSTMNT02/1000694',
#  'ESPORTSTMNT03/2007554',
#  'TRKR1/450251',
#  'TRKR1/690324',
#  'TRKR1/720425',
#  'ESPORTSTMNT06/731660',
#  'ESPORTSTMNT06/761094',
#  'ESPORTSTMNT02/1415116',
#  'ESPORTSTMNT06/300650',
#  'ESPORTSTMNT06/30435',
#  'ESPORTSTMNT03/1816145',
#  'ESPORTSTMNT01/1325066',
#  'ESPORTSTMNT06/41011',
#  'ESPORTSTMNT03/1764121',
#  'ESPORTSTMNT06/270382',
#  'ESPORTSTMNT01/1155902',
#  'TRKR1/920033',
#  'ESPORTSTMNT06/731624',
#  'ESPORTSTMNT06/780158',
#  'ESPORTSTMNT01/1152584',
#  'ESPORTSTMNT06/90570',
#  'TRKR1/450122',
#  'ESPORTSTMNT01/1084187',
#  'TRKR1/1010056',
#  'TRKR1/1010053',
#  'ESPORTSTMNT01/1292974',
#  'TRKR1/630312',
#  'ESPORTSTMNT06/130256',
#  'ESPORTSTMNT01/1424300',
#  'TRKR1/490129',
#  'ESPORTSTMNT06/760714',
#  'ESPORTSTMNT06/270442',
#  'ESPORTSTMNT01/1306165',
#  'ESPORTSTMNT01/1083842',
#  'ESPORTSTMNT06/740542',
#  'ESPORTSTMNT05/1831456',
#  'ESPORTSTMNT02/1405151',
#  'ESPORTSTMNT01/1694012',
#  'ESPORTSTMNT03/2074833',
#  'ESPORTSTMNT06/300189',
#  'ESPORTSTMNT01/1325229',
#  'TRKR1/1010327',
#  'ESPORTSTMNT01/1883205',
#  'ESPORTSTMNT01/1042168',
#  'ESPORTSTMNT02/1101938',
#  'ESPORTSTMNT06/800678',
#  'ESPORTSTMNT03/1116958',
#  'ESPORTSTMNT01/1894384',
#  'TRKR1/1000116',
#  'ESPORTSTMNT06/620616',
#  'TRKR1/550266',
#  'ESPORTSTMNT01/1293964',
#  'TRKR1/450226',
#  'TRKR1/640273',
#  'ESPORTSTMNT02/1286682',
#  'ESPORTSTMNT03/1415585',
#  'ESPORTSTMNT01/1144747',
#  'ESPORTSTMNT06/80197',
#  'ESPORTSTMNT03/1403600',
#  'ESPORTSTMNT06/80880',
#  'ESPORTSTMNT01/1720707',
#  'TRKR1/730322',
#  'ESPORTSTMNT06/721233',
#  'ESPORTSTMNT06/290038',
#  'ESPORTSTMNT02/1733774',
#  'TRKR1/610038',
#  'ESPORTSTMNT02/1081655',
#  'ESPORTSTMNT02/2065053',
#  'ESPORTSTMNT01/1165976',
#  'ESPORTSTMNT06/551575',
#  'ESPORTSTMNT03/1405626',
#  'ESPORTSTMNT06/740834',
#  'ESPORTSTMNT01/1161934',
#  'ESPORTSTMNT03/1415775',
#  'ESPORTSTMNT03/1113147',
#  'ESPORTSTMNT03/1404129',
#  'TRKR1/650131',
#  'ESPORTSTMNT06/810190',
#  'TRKR1/730073',
#  'TRKR1/1040883',
#  'TRKR1/1080796',
#  'ESPORTSTMNT06/720877',
#  'ESPORTSTMNT01/1071489',
#  'ESPORTSTMNT03/1125094',
#  'ESPORTSTMNT06/360385',
#  'TRKR1/690333',
#  'TRKR1/1160524',
#  'TRKR1/910095',
#  'ESPORTSTMNT02/1733887',
#  'ESPORTSTMNT03/1996296',
#  'TRKR1/570060',
#  'TRKR1/460156',
#  'ESPORTSTMNT01/1885092',
#  'TRKR1/440053',
#  'ESPORTSTMNT06/90754',
#  'ESPORTSTMNT02/1011098',
#  'TRKR1/920146',
#  'ESPORTSTMNT06/740796',
#  'TRKR1/660193',
#  'ESPORTSTMNT01/1425732',
#  'TRKR1/1030610',
#  'ESPORTSTMNT06/720790',
#  'TRKR1/710206',
#  'ESPORTSTMNT01/1154679',
#  'ESPORTSTMNT06/581417',
#  'TRKR1/1070302',
#  'ESPORTSTMNT02/1034217',
#  'TRKR1/730172',
#  'TRKR1/910357',
#  'TRKR1/740131',
#  'TRKR1/970143',
#  'TRKR1/660178',
#  'TRKR1/1150700',
#  'ESPORTSTMNT02/1021175',
#  'ESPORTSTMNT03/1415624',
#  'TRKR1/570080',
#  'ESPORTSTMNT06/541346',
#  'ESPORTSTMNT03/1113199',
#  'TRKR1/960292',
#  'ESPORTSTMNT01/1165560',
#  'TRKR1/610202',
#  'TRKR1/950589',
#  'TRKR1/500166',
#  'ESPORTSTMNT03/2007485',
#  'TRKR1/510075',
#  'ESPORTSTMNT06/720765',
#  'ESPORTSTMNT06/250733',
#  'ESPORTSTMNT06/770624',
#  'ESPORTSTMNT06/771721',
#  'ESPORTSTMNT01/1887390',
#  'ESPORTSTMNT02/1294689',
#  'TRKR1/650034',
#  'ESPORTSTMNT01/2137473',
#  'TRKR1/640116',
#  'ESPORTSTMNT02/1960637',
#  'ESPORTSTMNT06/641668',
#  'ESPORTSTMNT06/330829',
#  'ESPORTSTMNT06/601111',
#  'TRKR1/1030104',
#  'ESPORTSTMNT05/1830237',
#  'ESPORTSTMNT03/1765150',
#  'TRKR1/580100',
#  'TRKR1/1000029',
#  'ESPORTSTMNT06/630359',
#  'ESPORTSTMNT06/761889',
#  'TRKR1/500212',
#  'ESPORTSTMNT02/1384780',
#  'ESPORTSTMNT06/270556',
#  'ESPORTSTMNT02/1093630',
#  'TRKR1/1030897',
#  'ESPORTSTMNT02/2076419',
#  'ESPORTSTMNT06/540851',
#  'ESPORTSTMNT01/2149659',
#  'TRKR1/1090609',
#  'ESPORTSTMNT02/1080555',
#  'ESPORTSTMNT01/1051690',
#  'TRKR1/710082',
#  'TRKR1/920081',
#  'ESPORTSTMNT03/1442006',
#  'ESPORTSTMNT01/2136240',
#  'ESPORTSTMNT06/750151',
#  'TRKR1/920394',
#  'ESPORTSTMNT01/1884446',
#  'ESPORTSTMNT06/370287',
#  'ESPORTSTMNT03/1405504',
#  'ESPORTSTMNT06/30432',
#  'TRKR1/1020230',
#  'ESPORTSTMNT02/1101888',
#  'ESPORTSTMNT01/1690585',
#  'TRKR1/1090062',
#  'ESPORTSTMNT02/1095310',
#  'ESPORTSTMNT03/2073777',
#  'ESPORTSTMNT06/630127',
#  'ESPORTSTMNT02/1926957',
#  'ESPORTSTMNT03/1431616',
#  'TRKR1/680200',
#  'ESPORTSTMNT02/2067520',
#  'ESPORTSTMNT01/1306406',
#  'ESPORTSTMNT06/790635',
#  'ESPORTSTMNT02/1405142',
#  'ESPORTSTMNT03/1994661',
#  'ESPORTSTMNT01/1083258',
#  'ESPORTSTMNT01/1162038',
#  'ESPORTSTMNT02/1324775',
#  'ESPORTSTMNT06/340852',
#  'ESPORTSTMNT01/1050569',
#  'ESPORTSTMNT02/1333497',
#  'ESPORTSTMNT01/1132838',
#  'ESPORTSTMNT02/1294231',
#  'TRKR1/450381',
#  'ESPORTSTMNT02/1024721',
#  'ESPORTSTMNT06/790625',
#  'TRKR1/650038',
#  'TRKR1/1070998',
#  'ESPORTSTMNT05/1200114',
#  'TRKR1/710091',
#  'ESPORTSTMNT01/1294784',
#  'ESPORTSTMNT03/2054305',
#  'ESPORTSTMNT06/772057',
#  'ESPORTSTMNT06/772148',
#  'TRKR1/540109',
#  'ESPORTSTMNT03/1997576',
#  'ESPORTSTMNT06/330639',
#  'ESPORTSTMNT03/1352840',
#  'ESPORTSTMNT06/270459',
#  'ESPORTSTMNT01/1305843',
#  'ESPORTSTMNT06/551155',
#  'TRKR1/1140608',
#  'ESPORTSTMNT01/1084609',
#  'TRKR1/890113',
#  'ESPORTSTMNT02/1031773',
#  'TRKR1/1080426',
#  'TRKR1/700036',
#  'ESPORTSTMNT06/140713',
#  'ESPORTSTMNT02/1113946',
#  'TRKR1/610070',
#  'ESPORTSTMNT06/591355',
#  'TRKR1/720097',
#  'ESPORTSTMNT06/280519',
#  'ESPORTSTMNT06/350445',
#  'TRKR1/1030188',
#  'ESPORTSTMNT06/300143',
#  'TRKR1/700027',
#  'TRKR1/1010341',
#  'ESPORTSTMNT05/1200115',
#  'ESPORTSTMNT06/250994',
#  'ESPORTSTMNT06/290056',
#  'ESPORTSTMNT06/731236',
#  'ESPORTSTMNT06/761501',
#  'ESPORTSTMNT06/580859',
#  'ESPORTSTMNT02/1970597',
#  'ESPORTSTMNT06/800231',
#  'ESPORTSTMNT06/250653',
#  'ESPORTSTMNT01/1405624',
#  'ESPORTSTMNT06/581103',
#  'ESPORTSTMNT02/1334673',
#  'ESPORTSTMNT02/1385913',
#  'ESPORTSTMNT02/1383977',
#  'ESPORTSTMNT03/2101699',
#  'ESPORTSTMNT02/1113984',
#  'TRKR1/1110065',
#  'ESPORTSTMNT01/1691681',
#  'ESPORTSTMNT06/330696',
#  'TRKR1/1020538',
#  'ESPORTSTMNT03/1021430',
#  'ESPORTSTMNT06/762396',
#  'ESPORTSTMNT06/610554',
#  'TRKR1/990441',
#  'ESPORTSTMNT01/1294750',
#  'ESPORTSTMNT01/1166043',
#  'ESPORTSTMNT02/1394402',
#  'ESPORTSTMNT06/830210',
#  'ESPORTSTMNT06/270965',
#  'ESPORTSTMNT06/270350',
#  'ESPORTSTMNT06/180171',
#  'ESPORTSTMNT06/740825',
#  'TRKR1/1041038',
#  'TRKR1/1040466',
#  'TRKR1/890083',
#  'ESPORTSTMNT01/1693596',
#  'TRKR1/1130229',
#  'TRKR1/640278',
#  'ESPORTSTMNT03/1133901',
#  'ESPORTSTMNT03/1128337',
#  'ESPORTSTMNT06/770790',
#  'ESPORTSTMNT02/1003080',
#  ...}

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32610 entries, TRKR1/440018 to ESPORTSTMNT03/2102467
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   league    32610 non-null  object
#  1   year      32610 non-null  int64
#  2   split     32610 non-null  object
#  3   date      32610 non-null  object
#  4   playerid  32610 non-null  int64
#  5   side      32610 non-null  int64
#  6   position  32610 non-null  object
#  7   player    32610 non-null  object
#  8   team      32610 non-null  object
#  9   champion  32610 non-null  object
#  10  result    32610 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 3.0+ MB

# %%
def change_name(x):
    if x=='Ssol':
        return 'SS'
    if x=='Yeongjae':
        return 'YoungJae'
    else:
        return x

# %%
all_data['date']=pd.to_datetime(all_data['date'])

# %%
count=0
for elem in index:
    season=all_data.loc[elem]['split'].iloc[0]
    year=all_data.loc[elem]['year'].iloc[0]-2000
    date=all_data.loc[elem]['date'].iloc[0]
    if year==21 and season=='Summer':
        all_data.drop(index=elem,inplace=True)
        continue
    season_duration_data=season_duration['{0}{1}'.format(year,season)]
    if not (season_duration_data[0]<=date<season_duration_data[1]):
        all_data.drop(index=elem,inplace=True)

# %%
all_data['player']=all_data['player'].apply(change_name)

# %%
all_data.to_csv('./data_after/match.csv',index=True)
